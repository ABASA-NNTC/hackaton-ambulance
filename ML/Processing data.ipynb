# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#    Unnamed: 0       date  number  patient     age  \
# 0           0 2020-01-01    8(8)      NaN  26 лет
# 1           1 2020-01-01  16(16)      NaN  68 лет
# 2           2 2020-01-01  21(21)      NaN   1 лет
# 3           3 2020-01-01  28(28)      NaN   8 лет
# 4           4 2020-01-01  29(29)      NaN  79 лет
#
#                                       called by  \
# 0  родственник, проживающий совместно с больным
# 1                      больной или пострадавший
# 2                      больной или пострадавший
# 3  родственник, проживающий совместно с больным
# 4                      больной или пострадавший
#
#                                              address                Occasion  \
# 0                                                NaN   Температура, взрослый
# 1        г.Нижний Новгород, ш. Казанское, д.9, кв***  Болит живот (взрослый)
# 2  г.Нижний Новгород, ул. Родионова, д.167, корп....                     NaN
# ...

# %%
df = df.replace('None', np.NaN)

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# 0       1
# 1073    1
# 1071    1
# 1070    1
# 1069    1
#        ..
# 530     1
# 529     1
# 528     1
# 527     1
# 1596    1
# Name: Unnamed: 0, Length: 1597, dtype: int64
# 2020-01-31    142
# 2020-01-26    139
# 2020-01-25    122
# 2020-01-28    118
# 2020-01-23    108
# 2020-01-27    106
# 2020-01-30    103
# 2020-01-24     98
# 2020-01-29     97
# 2020-01-19     96
# 2020-01-22     79
# 2020-01-21     71
# 2020-01-20     65
# 2020-01-18     50
# 2020-01-17     34
# 2020-01-16     22
# 2020-01-15     14
# 2020-01-11     13
# 2020-01-01     12
# 2020-01-05     10
# 2020-01-14      9
# 2020-01-13      8
# 2020-01-12      8
# 2020-01-07      8
# 2020-01-03      8
# 2020-01-02      7
# 2020-01-09      6
# 2020-01-06      6
# 2020-01-08      4
# 2020-01-10      2
# 2020-01-04      2
# Name: date, dtype: int64
# 8(8)          1
# 12624(525)    1
# 12616(517)    1
# 12561(462)    1
# 12559(460)    1
#              ..
# 6608(611)     1
# 6606(609)     1
# 6854(857)     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1597 entries, 0 to 1596
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1597 non-null   int64
#  1   date           1567 non-null   datetime64[ns]
#  2   number         1597 non-null   object
#  3   patient        0 non-null      float64
#  4   age            1597 non-null   object
#  5   called by      1276 non-null   object
#  6   address        682 non-null    object
#  7   Occasion       1476 non-null   object
#  8   Call Type      1596 non-null   object
#  9   Sick Type      1592 non-null   object
#  10  Diagnose       1521 non-null   object
#  11  Result         1541 non-null   object
#  12  Delivered to   1597 non-null   object
#  13  brigade        0 non-null      float64
#  14  substation     1567 non-null   object
#  15  Accepted time  1597 non-null   datetime64[ns]
#  16  Arrived time   1597 non-null   datetime64[ns]
# ...

# %%
df = df.drop(['sick', 'address'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df = df.drop(['sick', 'address'], axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format="%Y-%m-%d %H:%M:%S")
df['accepted'] = pd.to_datetime(df['accepted'], format="%Y-%m-%d %H:%M:%S")

# %%
df

# %%
df['firstNum'] = df['number'][~df['number'].isnull()].astype(str).apply(lambda x: x.split('(')[0])
df['addNum'] = df['number'][~df['number'].isnull()].astype(str).apply(lambda x: x.split('(')[1][:-1])

# %%
df = df.drop(['firstNum', 'addNum', 'number'], axis=1)

# %%
df.info()

# %%
df[['date', 'arrival']].set_index()

# %%
df[~df['date'].isnull()]['date'].dt.date

# %%
df[~df['date'].isnull()].set_index(df[~df['date'].isnull()]['date'].dt.date)

# %%
df_weather = pd.read_excel('additionalData/weather/2020.xls', skiprows=6)

# %%
df_weather

# %%
df = df.rename({'date':'datetime'}, axis=1)
df_weather = df_weather.rename({'date':'datetime'}, axis=1)

# %%
df['datetime'].dt

# %%
df['date'] = df['datetime'].dt.date
df_weather['date'] = df_weather['datetime'].dt.date

# %%
df.drop('datetime', axis=1)

# %%
df = df.drop('datetime', axis=1)

# %%
df_weather = df_weather.rename({'Местное время в Нижнем Новгороде': 'date'}, axis=1)

# %%
df_weather.set_index('date')

# %%
new_df = df.set_index('date').join(df_weather.set_index('date'), on='date')

# %%
new_df.reset_index()['date']
